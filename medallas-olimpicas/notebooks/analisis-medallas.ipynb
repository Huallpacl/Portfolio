# %%
import pandas as pd

# Cargar el archivo CSV
df = pd.read_csv("../data/medallas.csv")
df.head()
# Out:
#                 País  Participaciones Oro  Plata  Bronce Total
# 0  Afghanistan (AFG)               16   0      0       2     2
# 1      Albania (ALB)               10   0      0       2     2
# 2      Algeria (ALG)               15   7      4       9    20
# 3    Argentina (ARG)               26  22     27      31    80
# 4      Armenia (ARM)                8   2     11       9    22

# %%
# Convertir columnas a enteros
for col in ["Oro", "Plata", "Bronce", "Total"]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# Revisar datos nulos
df.isnull().sum()
# Out:
# País               0
# Participaciones    0
# Oro                1
# Plata              0
# Bronce             0
# Total              2
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Top 10 países por medallas totales
top10 = df.sort_values("Total", ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.bar(top10["País"], top10["Total"], color="gold")
plt.title("Top 10 países con más medallas")
plt.ylabel("Total de medallas")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
